# %%
import pandas as pd
import numpy as np

frame = pd.DataFrame( np.random.random((4,4)),
index = ['white','black','red','blue'],
columns = ['up','down','right','left'])

frame
# Out:
#              up      down     right      left
# white  0.232179  0.478662  0.043433  0.051243
# black  0.375519  0.608131  0.644484  0.589323
# red    0.226974  0.681039  0.471066  0.363521
# blue   0.347595  0.283811  0.876091  0.636525

# %%
s = []
s.append('<HTML>')
s.append('<HEAD><TITLE>df to html</TITLE></HEAD>')
s.append('<BODY>')
s.append(frame.to_html())
s.append('</BODY></HTML>')
html=''.join(s)
html
# Out:
# '<HTML><HEAD><TITLE>df to html</TITLE></HEAD><BODY><table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>up</th>\n      <th>down</th>\n      <th>right</th>\n      <th>left</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>white</th>\n      <td>0.420662</td>\n      <td>0.587224</td>\n      <td>0.616084</td>\n      <td>0.731522</td>\n    </tr>\n    <tr>\n      <th>black</th>\n      <td>0.086988</td>\n      <td>0.602037</td>\n      <td>0.197698</td>\n      <td>0.627058</td>\n    </tr>\n    <tr>\n      <th>red</th>\n      <td>0.232725</td>\n      <td>0.694083</td>\n      <td>0.217597</td>\n      <td>0.280666</td>\n    </tr>\n    <tr>\n      <th>blue</th>\n      <td>0.981283</td>\n      <td>0.757962</td>\n      <td>0.988453</td>\n      <td>0.256259</td>\n    </tr>\n  </tbody>\n</table></BODY></HTML>'

# %%
with open('df_html.html','w', encoding='utf-8') as fout:
    fout.write(html)
    
print('성공')
# Out:
# 성공

# %%
r = pd.read_html('df_html.html')
r
# Out:
# [  Unnamed: 0        up      down     right      left
#  0      white  0.420662  0.587224  0.616084  0.731522
#  1      black  0.086988  0.602037  0.197698  0.627058
#  2        red  0.232725  0.694083  0.217597  0.280666
#  3       blue  0.981283  0.757962  0.988453  0.256259]

# %%
web_frames = pd.read_html('df_html.html', index_col=0)
web_frames[0]
# Out:
#              up      down     right      left
# white  0.420662  0.587224  0.616084  0.731522
# black  0.086988  0.602037  0.197698  0.627058
# red    0.232725  0.694083  0.217597  0.280666
# blue   0.981283  0.757962  0.988453  0.256259

# %%
ranking =pd.read_html('https://finance.naver.com/item/sise.naver?code=005930', encoding='euc-kr'
) 
ranking
# Out:
# [                    0                                        1  \
#  0  전일  58,600  58,600  고가  58,90058,900  (상한가  76,10076,100  )
#  1    시가  58,70058,700        저가  58,30058,300  (하한가  41,100  )
#
#                              2
#  0   거래량  2,813,788  2,813,788
#  1  거래대금  164,709  164,709  백만  ,
#             0            1       2           3
#  0        현재가        58400    매도호가       58400
#  1       전일대비      하락  200    매수호가       58300
#  2     등락률(%)       -0.34%     전일가       58600
#  3        거래량      2813788      시가       58700
#  4   거래대금(백만)       164709      고가       58900
#  5        액면가         100원      저가       58300
#  6        NaN          NaN     NaN         NaN
#  7        상한가        76100    전일상한       78000
#  8        하한가        41100    전일하한       42000
#  9        PER         8.86     EPS        6593
#  10    52주 최고        80800  52주 최저       55700
#  11      시가총액  3,486,353억원   상장주식수  5969782550
#  12     외국인현재  2,972,910천주     자본금   778,046백만,
# ...

# %%
frame = pd.DataFrame(np.arange(16).reshape(4,4),
index=['white','black','red','blue'],
columns=['up','down','right','left'])
frame.to_json('frame.json')

frame
# Out:
#        up  down  right  left
# white   0     1      2     3
# black   4     5      6     7
# red     8     9     10    11
# blue   12    13     14    15

# %%
{"up":{"white":0,"black":4,"red":8,"blue":12},"down":{"white":1,"black":5, 
"red":9,"blue":13},"right":{"white":2,"black":6,"red":10,"blue":14}, 
"left":{"white":3,"black":7,"red":11,"blue":15}}
# Out:
# {'up': {'white': 0, 'black': 4, 'red': 8, 'blue': 12},
#  'down': {'white': 1, 'black': 5, 'red': 9, 'blue': 13},
#  'right': {'white': 2, 'black': 6, 'red': 10, 'blue': 14},
#  'left': {'white': 3, 'black': 7, 'red': 11, 'blue': 15}}

# %%
pd.read_json('frame.json')
# Out:
#        up  down  right  left
# white   0     1      2     3
# black   4     5      6     7
# red     8     9     10    11
# blue   12    13     14    15

# %%
from pandas.io.json import json_normalize
import json

# %%
book='''[{"writer": "Mark Ross",
 "nationality": "USA",
 "books": [
 {"title": "XML Cookbook", "price": 23.56},
 {"title": "Python Fundamentals", "price": 50.70},
 {"title": "The NumPy library", "price": 12.30}
 ]
},{"writer": "Barbara Bracket",
 "nationality": "UK",
 "books": [
 {"title": "Java Enterprise", "price": 28.60},
 {"title": "HTML5", "price": 31.35},
 {"title": "Python for Dummies", "price": 28.00}
 ]
}]'''


with open('books.json','w',encoding='utf-8') as fout:
    fout.write(book)

# %%
file = open('books.json','r')
text = file.read()
text = json.loads(text)
text
# Out:
# [{'writer': 'Mark Ross',
#   'nationality': 'USA',
#   'books': [{'title': 'XML Cookbook', 'price': 23.56},
#    {'title': 'Python Fundamentals', 'price': 50.7},
#    {'title': 'The NumPy library', 'price': 12.3}]},
#  {'writer': 'Barbara Bracket',
#   'nationality': 'UK',
#   'books': [{'title': 'Java Enterprise', 'price': 28.6},
#    {'title': 'HTML5', 'price': 31.35},
#    {'title': 'Python for Dummies', 'price': 28.0}]}]

# %%
frame = pd.DataFrame(np.arange(16).reshape(4,4), index = 
['up','down','left','right'])
frame.to_pickle('frame.pkl')

# %%
pd.read_pickle('frame.pkl')
# Out:
#         0   1   2   3
# up      0   1   2   3
# down    4   5   6   7
# left    8   9  10  11
# right  12  13  14  15

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://alsrud123:nightmare1@cluster0.asx4cgo.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client['test']
db
# Out:
# Database(MongoClient(host=['ac-fzcv6js-shard-00-00.asx4cgo.mongodb.net:27017', 'ac-fzcv6js-shard-00-02.asx4cgo.mongodb.net:27017', 'ac-fzcv6js-shard-00-01.asx4cgo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-12smh6-shard-0', tls=True), 'test')

# %%
db.list_collection_names()
# Out:
# ['test']

# %%
test=db['test']

# %%
mydict={"name":"Lauua","address":"Seoul"}
x=test.insert_one(mydict)
x.inserted_id
# Out:
# ObjectId('630dca5bbc26aeb3eb1873f3')

# %%
cusor=test.find()
cusor
df=pd.DataFrame(list(cusor))

# %%
df = df.drop(columns=['_id'])
df
# Out:
#     name address
# 0  Lauua   Seoul

# %%
for doc in cusor:
    print(doc['name'])
    print(doc['address'])

# %%
x= test.delete_one({'name':'Lauua'})
x

# %%
for doc in cusor:
    print(doc['address'])

# %%
import pandas as pd
import numpy as np

frame = pd.DataFrame( np.arange(50).reshape(10,-1),
    columns=['white','red','blue','black','green'])
frame
# Out:
#    white  red  blue  black  green
# 0      0    1     2      3      4
# 1      5    6     7      8      9
# 2     10   11    12     13     14
# 3     15   16    17     18     19
# 4     20   21    22     23     24
# 5     25   26    27     28     29
# 6     30   31    32     33     34
# 7     35   36    37     38     39
# 8     40   41    42     43     44
# 9     45   46    47     48     49

# %%
import json
record =json.loads(frame.T.to_json()).values()
record
# Out:
# dict_values([{'white': 0, 'red': 1, 'blue': 2, 'black': 3, 'green': 4}, {'white': 5, 'red': 6, 'blue': 7, 'black': 8, 'green': 9}, {'white': 10, 'red': 11, 'blue': 12, 'black': 13, 'green': 14}, {'white': 15, 'red': 16, 'blue': 17, 'black': 18, 'green': 19}, {'white': 20, 'red': 21, 'blue': 22, 'black': 23, 'green': 24}, {'white': 25, 'red': 26, 'blue': 27, 'black': 28, 'green': 29}, {'white': 30, 'red': 31, 'blue': 32, 'black': 33, 'green': 34}, {'white': 35, 'red': 36, 'blue': 37, 'black': 38, 'green': 39}, {'white': 40, 'red': 41, 'blue': 42, 'black': 43, 'green': 44}, {'white': 45, 'red': 46, 'blue': 47, 'black': 48, 'green': 49}])

# %%
x=test.insert_many(record)
x.inserted_ids
# Out:
# [ObjectId('630dcee3bc26aeb3eb187408'),
#  ObjectId('630dcee3bc26aeb3eb187409'),
#  ObjectId('630dcee3bc26aeb3eb18740a'),
#  ObjectId('630dcee3bc26aeb3eb18740b'),
#  ObjectId('630dcee3bc26aeb3eb18740c'),
#  ObjectId('630dcee3bc26aeb3eb18740d'),
#  ObjectId('630dcee3bc26aeb3eb18740e'),
#  ObjectId('630dcee3bc26aeb3eb18740f'),
#  ObjectId('630dcee3bc26aeb3eb187410'),
#  ObjectId('630dcee3bc26aeb3eb187411')]

# %%
cursor = test.find()

# %%
df=pd.DataFrame(list(cursor))
df
# Out:
#                          _id  white  red  blue  black  green
# 0   630dccbebc26aeb3eb1873fe      0    1     2      3      4
# 1   630dccbebc26aeb3eb1873ff      5    6     7      8      9
# 2   630dccbebc26aeb3eb187400     10   11    12     13     14
# 3   630dccbebc26aeb3eb187401     15   16    17     18     19
# 4   630dccbebc26aeb3eb187402     20   21    22     23     24
# 5   630dccbebc26aeb3eb187403     25   26    27     28     29
# 6   630dccbebc26aeb3eb187404     30   31    32     33     34
# 7   630dccbebc26aeb3eb187405     35   36    37     38     39
# 8   630dccbebc26aeb3eb187406     40   41    42     43     44
# 9   630dccbebc26aeb3eb187407     45   46    47     48     49
# 10  630dcee3bc26aeb3eb187408      0    1     2      3      4
# 11  630dcee3bc26aeb3eb187409      5    6     7      8      9
# 12  630dcee3bc26aeb3eb18740a     10   11    12     13     14
# 13  630dcee3bc26aeb3eb18740b     15   16    17     18     19
# ...

# %%
df = df.drop(columns=['_id'])
df
# Out:
#     white  red  blue  black  green
# 0       0    1     2      3      4
# 1       5    6     7      8      9
# 2      10   11    12     13     14
# 3      15   16    17     18     19
# 4      20   21    22     23     24
# 5      25   26    27     28     29
# 6      30   31    32     33     34
# 7      35   36    37     38     39
# 8      40   41    42     43     44
# 9      45   46    47     48     49
# 10      0    1     2      3      4
# 11      5    6     7      8      9
# 12     10   11    12     13     14
# 13     15   16    17     18     19
# 14     20   21    22     23     24
# 15     25   26    27     28     29
# 16     30   31    32     33     34
# 17     35   36    37     38     39
# 18     40   41    42     43     44
# 19     45   46    47     48     49

# %%
query={'white':{'$gt':30}}#white에서 30보다 큰거 가져와라

cursor=test.find(query).sort('white',-1)#sort는 정렬(오름차순), 안에-1을 넣으면 내림차순
df=pd.DataFrame(list(cursor)).drop('_id',axis=1)
df
# Out:
#    white  red  blue  black  green
# 0     45   46    47     48     49
# 1     45   46    47     48     49
# 2     40   41    42     43     44
# 3     40   41    42     43     44
# 4     35   36    37     38     39
# 5     35   36    37     38     39

# %%
query={'white':{'$gt':30}}
x=test.delete_one(query)
x.deleted_count
# Out:
# 1

# %%
query={'white':{'$gt':30}}
new={"$set":{"address":"서울시 관악구"}}#set은 수정
x=test.update_one(query,new)
x.modified_count
# Out:
# 1

# %%
test.drop()#컬렉션 삭제

# %%
test.find.limit(5)#다섯개만 가져옴
